# %%
from keras.models import load_model

# returns a compiled model
# identical to the previous one
model = load_model('emotion_model_sequential.h5')
# Out:
# C:\Users\abdur\anaconda3\envs\cv_env\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# C:\Users\abdur\anaconda3\envs\cv_env\lib\site-packages\keras\src\optimizers\base_optimizer.py:86: UserWarning: Argument `decay` is no longer supported and will be ignored.
#   warnings.warn(
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:absl:Error in loading the saved optimizer state. As a result, your model is starting with a freshly initialized optimizer.

# %%
# !pip install tensorflow opencv-python numpy pillow tkinter
# Out:
# ...
# ERROR: Could not find a version that satisfies the requirement tkinter (from versions: none)
# ERROR: No matching distribution found for tkinter

# %%
import cv2
import numpy as np
import tensorflow as tf

# Load the trained model
try:
    model = tf.keras.models.load_model('emotion_model_sequential.h5')
    print("Model loaded successfully.")
except Exception as e:
    print(f"Error loading model: {e}")
    exit()

# Emotion labels
emotion_labels = ['angry', 'disgust', 'fear', 'happy', 'neutral', 'sad', 'surprise']
emotion_colors = {
    'angry': (0, 0, 255),       # Red
    'disgust': (0, 255, 0),      # Green
    'fear': (255, 0, 255),       # Purple
    'happy': (0, 255, 255),      # Yellow
    'neutral': (128, 128, 128),  # Gray
    'sad': (255, 0, 0),          # Blue
    'surprise': (0, 165, 255)    # Orange
}

# Confidence threshold
CONFIDENCE_THRESHOLD = 0.2  # Change this to your desired threshold

# Open the webcam
cap = cv2.VideoCapture(0)

if not cap.isOpened():
    print("Error: Could not open webcam.")
    exit()

# Load face detector
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

while True:
    ret, frame = cap.read()
    if not ret:
        print("Error: Failed to capture frame.")
        break

    # Convert frame to grayscale for face detection
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

    # Detect faces in the frame
    faces = face_cascade.detectMultiScale(gray, scaleFactor=1.2, minNeighbors=6, minSize=(30, 30))

    for (x, y, w, h) in faces:
        # Extract and preprocess the face
        face = gray[y:y+h, x:x+w]
        face_resized = cv2.resize(face, (224, 224))  # Resize to match model input
        face_resized = face_resized / 255.0  # Normalize pixel values
        face_resized = np.expand_dims(face_resized, axis=0)  # Add batch dimension
        face_resized = np.expand_dims(face_resized, axis=-1)  # Add channel dimension (grayscale)

        # Predict emotion
        predictions = model.predict(face_resized)[0]  # Get prediction array
        max_confidence = np.max(predictions)  # Get the highest confidence score
        emotion_idx = np.argmax(predictions)  # Get the index of the predicted emotion

        # If confidence is below threshold, display "Uncertain"
        if max_confidence < CONFIDENCE_THRESHOLD:
            emotion = "Uncertain"
            color = (128, 128, 128)  # Gray
            label = "Uncertain"
        else:
            emotion = emotion_labels[emotion_idx]
            color = emotion_colors[emotion]
            label = f"{emotion} ({max_confidence:.2f})"

        # Draw rectangle and label
        cv2.rectangle(frame, (x, y), (x+w, y+h), color, 2)
        cv2.putText(frame, label, (x, y-10), cv2.FONT_HERSHEY_SIMPLEX, 0.9, color, 2)

    # Display the frame
    cv2.imshow('Real-Time Emotion Detection', frame)

    # Exit on 'q' key
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Cleanup
cap.release()
cv2.destroyAllWindows()
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:absl:Error in loading the saved optimizer state. As a result, your model is starting with a freshly initialized optimizer.
# Model loaded successfully.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 337ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# ...

# %%
from keras.models import load_model
import cv2
import tensorflow as tf
import numpy as np

# Load the emotion detection model
try:
    model = tf.keras.models.load_model('new_classification _emotion_detection_model.h5')  # Correct filename
except Exception as e:
    print(f"Error loading model: {e}")
    exit()

# Emotion labels and colors
emotion_labels = ['angry', 'disgust', 'fear', 'happy', 'neutral', 'sad', 'surprise']
emotion_colors = {
    'angry': (0, 0, 255),       # Red
    'disgust': (0, 255, 0),      # Green
    'fear': (255, 0, 255),       # Purple
    'happy': (0, 255, 255),      # Yellow
    'neutral': (128, 128, 128),  # Gray
    'sad': (255, 0, 0),          # Blue
    'surprise': (0, 165, 255)    # Orange
}

# Initialize webcam
cap = cv2.VideoCapture(0)

if not cap.isOpened():
    print("Error: Could not open webcam.")
    exit()

# Load face detector
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

while True:
    ret, frame = cap.read()
    if not ret:
        print("Error: Failed to capture frame.")
        break

    # Convert frame to grayscale
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

    # Detect faces
    faces = face_cascade.detectMultiScale(gray, scaleFactor=1.1, minNeighbors=5, minSize=(30, 30))

    for (x, y, w, h) in faces:
        # Extract the face ROI and preprocess it
        face = gray[y:y+h, x:x+w]
        face_resized = cv2.resize(face, (224, 224))  # Resize to model input size (224x224)
        face_resized = face_resized / 255.0  # Normalize
        face_resized = np.expand_dims(face_resized, axis=0)  # Add batch dimension
        face_resized = np.expand_dims(face_resized, axis=-1)  # Add channel dimension (1 channel grayscale)

        # Ensure correct input shape before prediction
        if face_resized.shape != (1, 224, 224, 1):
            print("Error: Incorrect input shape for model prediction.")
            continue

        # Predict emotion
        predictions = model.predict(face_resized)
        emotion_idx = np.argmax(predictions)
        emotion = emotion_labels[emotion_idx]
        confidence = predictions[0][emotion_idx]

        # Only display prediction if confidence is above a threshold (e.g., 0.7)
        if confidence >= 0.7:
            # Draw rectangle and label
            color = emotion_colors[emotion]
            cv2.rectangle(frame, (x, y), (x+w, y+h), color, 2)
            cv2.putText(frame, f"{emotion} ({confidence:.2f})", (x, y-10), cv2.FONT_HERSHEY_SIMPLEX, 1, color, 2)
        else:
            # For low confidence, show "Uncertain"
            cv2.rectangle(frame, (x, y), (x+w, y+h), (128, 128, 128), 2)  # Gray rectangle
            cv2.putText(frame, "Uncertain", (x, y-10), cv2.FONT_HERSHEY_SIMPLEX, 1, (128, 128, 128), 2)

    # Display output frame
    cv2.imshow('Real-Time Classification Face Emotion Detection', frame)

    # Check for exit key
    key = cv2.waitKey(1) & 0xFF
    if key == ord('q'):
        break

# Release resources
cap.release()
cv2.destroyAllWindows()
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 754ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step
# ...

# %%
from keras.models import load_model
import cv2
import tensorflow as tf
import numpy as np

# Load the emotion detection model
try:
    model = tf.keras.models.load_model('emotion_model_sequential.h5')  # Correct filename
except Exception as e:
    print(f"Error loading model: {e}")
    exit()

# Emotion labels and colors
emotion_labels = ['angry', 'disgust', 'fear', 'happy', 'neutral', 'sad', 'surprise']
emotion_colors = {
    'angry': (0, 0, 255),       # Red
    'disgust': (0, 255, 0),      # Green
    'fear': (255, 0, 255),       # Purple
    'happy': (0, 255, 255),      # Yellow
    'neutral': (128, 128, 128),  # Gray
    'sad': (255, 0, 0),          # Blue
    'surprise': (0, 165, 255)    # Orange
}

# Initialize webcam
cap = cv2.VideoCapture(0)

if not cap.isOpened():
    print("Error: Could not open webcam.")
    exit()

# Load face detector
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

while True:
    ret, frame = cap.read()
    if not ret:
        print("Error: Failed to capture frame.")
        break

    # Convert frame to grayscale
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

    # Detect faces
    faces = face_cascade.detectMultiScale(gray, scaleFactor=1.1, minNeighbors=5, minSize=(30, 30))

    for (x, y, w, h) in faces:
        # Extract the face ROI and preprocess it
        face = gray[y:y+h, x:x+w]
        face_resized = cv2.resize(face, (224, 224))  # Resize to model input size (224x224)
        face_resized = face_resized / 255.0  # Normalize
        face_resized = np.expand_dims(face_resized, axis=0)  # Add batch dimension
        face_resized = np.expand_dims(face_resized, axis=-1)  # Add channel dimension (1 channel grayscale)

        # Ensure correct input shape before prediction
        if face_resized.shape != (1, 224, 224, 1):
            print("Error: Incorrect input shape for model prediction.")
            continue

        # Predict emotion
        predictions = model.predict(face_resized)
        emotion_idx = np.argmax(predictions)
        emotion = emotion_labels[emotion_idx]

        # Draw rectangle and label
        color = emotion_colors[emotion]
        cv2.rectangle(frame, (x, y), (x+w, y+h), color, 2)
        cv2.putText(frame, emotion, (x, y-10), cv2.FONT_HERSHEY_SIMPLEX, 1, color, 2)

    # Display output frame
    cv2.imshow('Classification Face Emotion Detection', frame)

    # Check for exit key
    key = cv2.waitKey(1) & 0xFF
    if key == ord('q'):
        break

# Release resources
cap.release()
cv2.destroyAllWindows()
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:absl:Error in loading the saved optimizer state. As a result, your model is starting with a freshly initialized optimizer.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 420ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# ...

# %%
import cv2
import tensorflow as tf
import numpy as np

# Load the emotion detection model
try:
    model = tf.keras.models.load_model('emotion_model_sequential.h55')
except Exception as e:
    print(f"Error loading model: {e}")
    exit()

# Emotion labels and colors
emotion_labels = ['angry', 'disgust', 'fear', 'happy', 'neutral', 'sad', 'surprise']
emotion_colors = {
    'angry': (0, 0, 255),       # Red
    'disgust': (0, 255, 0),      # Green
    'fear': (255, 0, 255),       # Purple
    'happy': (0, 255, 255),      # Yellow
    'neutral': (128, 128, 128),  # Gray
    'sad': (255, 0, 0),          # Blue
    'surprise': (0, 165, 255)    # Orange
}

# Initialize webcam
cap = cv2.VideoCapture(0)

if not cap.isOpened():
    print("Error: Could not open webcam.")
    exit()

# Load face detector
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

while True:
    ret, frame = cap.read()
    if not ret:
        print("Error: Failed to capture frame.")
        break

    # Convert frame to grayscale
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

    # Detect faces
    faces = face_cascade.detectMultiScale(gray, scaleFactor=1.1, minNeighbors=5, minSize=(30, 30))

    for (x, y, w, h) in faces:
        # Extract the face ROI and preprocess it
        face = gray[y:y+h, x:x+w]
        face_resized = cv2.resize(face, (48, 48))  # Resize to model input size
        face_resized = face_resized / 255.0  # Normalize
        face_resized = np.expand_dims(face_resized, axis=0)  # Add batch dimension
        face_resized = np.expand_dims(face_resized, axis=-1)  # Add channel dimension

        # Ensure correct input shape before prediction
        if face_resized.shape != (1, 48, 48, 1):
            print("Error: Incorrect input shape for model prediction.")
            continue

        # Predict emotion
        predictions = model.predict(face_resized)
        emotion_idx = np.argmax(predictions)
        emotion = emotion_labels[emotion_idx]

        # Draw rectangle and label
        color = emotion_colors[emotion]
        cv2.rectangle(frame, (x, y), (x+w, y+h), color, 2)
        cv2.putText(frame, emotion, (x, y-10), cv2.FONT_HERSHEY_SIMPLEX, 1, color, 2)

    # Display output frame
    cv2.imshow('Classification Face Emotion Detection', frame)

    # Check for exit key
    key = cv2.waitKey(1) & 0xFF
    if key == ord('q'):
        break

# Release resources
cap.release()
cv2.destroyAllWindows()
# Out:
# Error loading model: SavedModel file does not exist at: emotion_model_sequential.h55\{saved_model.pbtxt|saved_model.pb}
# WARNING:tensorflow:Model was constructed with shape (None, 224, 224, 1) for input KerasTensor(type_spec=TensorSpec(shape=(None, 224, 224, 1), dtype=tf.float32, name='conv2d_17_input'), name='conv2d_17_input', description="created by layer 'conv2d_17_input'"), but it was called on an input with incompatible shape (None, 48, 48, 1).
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 60
#      57     continue
#      59 # Predict emotion
# ---> 60 predictions = model.predict(face_resized)
#      61 emotion_idx = np.argmax(predictions)
#      62 emotion = emotion_labels[emotion_idx]
#
# ...

# %%
import cv2
import tensorflow as tf
import numpy as np

# Load the emotion detection model (correct file name)
try:
    model = tf.keras.models.load_model('emotion_model_sequential.h5')  # Correct file name
except Exception as e:
    print(f"Error loading model: {e}")
    exit()

# Emotion labels and colors
emotion_labels = ['angry', 'disgust', 'fear', 'happy', 'neutral', 'sad', 'surprise']
emotion_colors = {
    'angry': (0, 0, 255),       # Red
    'disgust': (0, 255, 0),      # Green
    'fear': (255, 0, 255),       # Purple
    'happy': (0, 255, 255),      # Yellow
    'neutral': (128, 128, 128),  # Gray
    'sad': (255, 0, 0),          # Blue
    'surprise': (0, 165, 255)    # Orange
}

# Initialize webcam
cap = cv2.VideoCapture(0)

if not cap.isOpened():
    print("Error: Could not open webcam.")
    exit()

# Load face detector
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

while True:
    ret, frame = cap.read()
    if not ret:
        print("Error: Failed to capture frame.")
        break

    # Convert frame to grayscale
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

    # Detect faces
    faces = face_cascade.detectMultiScale(gray, scaleFactor=1.1, minNeighbors=5, minSize=(30, 30))

    for (x, y, w, h) in faces:
        # Extract the face ROI and preprocess it
        face = gray[y:y+h, x:x+w]
        face_resized = cv2.resize(face, (224, 224))  # Resize to model input size (224x224)
        face_resized = face_resized / 255.0  # Normalize the pixel values to [0, 1]
        face_resized = np.expand_dims(face_resized, axis=0)  # Add batch dimension
        face_resized = np.expand_dims(face_resized, axis=-1)  # Add channel dimension (grayscale)

        # Ensure correct input shape before prediction
        if face_resized.shape != (1, 224, 224, 1):
            print("Error: Incorrect input shape for model prediction.")
            continue

        # Predict emotion
        predictions = model.predict(face_resized)
        emotion_idx = np.argmax(predictions)
        emotion = emotion_labels[emotion_idx]
        confidence = predictions[0][emotion_idx]

        # Only display prediction if confidence is above a threshold (e.g., 0.5)
        if confidence >= 0.5:
            # Draw rectangle and label
            color = emotion_colors[emotion]
            cv2.rectangle(frame, (x, y), (x+w, y+h), color, 2)
            cv2.putText(frame, f"{emotion} ({confidence:.2f})", (x, y-10), cv2.FONT_HERSHEY_SIMPLEX, 1, color, 2)
        else:
            # For low confidence, show "Uncertain"
            cv2.rectangle(frame, (x, y), (x+w, y+h), (128, 128, 128), 2)  # Gray rectangle
            cv2.putText(frame, "Uncertain", (x, y-10), cv2.FONT_HERSHEY_SIMPLEX, 1, (128, 128, 128), 2)

    # Display output frame
    cv2.imshow('Real-Time Emotion Detection', frame)

    # Check for exit key
    key = cv2.waitKey(1) & 0xFF
    if key == ord('q'):
        break

# Release resources
cap.release()
cv2.destroyAllWindows()

# %%
import cv2
import tensorflow as tf
import numpy as np

# Load the emotion detection model
model = tf.keras.models.load_model('child_emotion_detection_model.h5')

# Emotion labels
emotion_labels = ['angry', 'disgust', 'fear', 'happy', 'neutral', 'sad', 'surprise']

# Emotion colors mapping
emotion_colors = {
    'angry': (0, 0, 255),       # Red
    'disgust': (0, 255, 0),      # Green
    'fear': (255, 0, 255),       # Purple
    'happy': (0, 255, 255),      # Yellow
    'neutral': (128, 128, 128),  # Gray
    'sad': (255, 0, 0),          # Blue
    'surprise': (0, 165, 255)    # Orange
}

# Initialize webcam
cap = cv2.VideoCapture(0)

# Load OpenCV face detector
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

while True:
    ret, frame = cap.read()
    if not ret:
        print("Failed to capture frame")
        break

    # Convert frame to grayscale for face detection
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

    # Detect faces
    faces = face_cascade.detectMultiScale(gray, scaleFactor=1.1, minNeighbors=5, minSize=(30, 30))

    for (x, y, w, h) in faces:
        # Extract and preprocess face for emotion detection
        face = gray[y:y+h, x:x+w]  # Convert to grayscale
        face_resized = cv2.resize(face, (48, 48))  # Resize to model's input size
        face_resized = face_resized / 255.0  # Normalize pixel values
        face_resized = np.expand_dims(face_resized, axis=0)  # Add batch dimension
        face_resized = np.expand_dims(face_resized, axis=-1)  # Add channel dimension

        # Predict emotion
        predictions = model.predict(face_resized)
        emotion_idx = np.argmax(predictions)
        emotion = emotion_labels[emotion_idx]

        # Draw rectangle with corresponding emotion color
        color = emotion_colors[emotion]
        cv2.rectangle(frame, (x, y), (x+w, y+h), color, 2)
        cv2.putText(frame, emotion, (x, y-10), cv2.FONT_HERSHEY_SIMPLEX, 1, color, 2)

    # Display the processed frame
    cv2.imshow('Emotion Detection', frame)

    # Exit on 'q' key press
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 49
#      46 face_resized = np.expand_dims(face_resized, axis=-1)  # Add channel dimension
#      48 # Predict emotion
# ---> 49 predictions = model.predict(face_resized)
#      50 emotion_idx = np.argmax(predictions)
#      51 emotion = emotion_labels[emotion_idx]
#
# File ~\anaconda3\envs\tf-env\lib\site-packages\keras\engine\training.py:1751, in Model.predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    1749 for step in data_handler.steps():
#    1750   callbacks.on_predict_batch_begin(step)
# -> 1751   tmp_batch_outputs = self.predict_function(iterator)
#    1752   if data_handler.should_sync:
#    1753     context.async_wait()
#
# ...

# %%
import cv2
import tensorflow as tf
import numpy as np

# Load the emotion detection model (make sure the model path is correct)
model = tf.keras.models.load_model('new_classification_emotion_detection_model.h5')

# Emotion labels
emotion_labels = ['angry', 'disgust', 'fear', 'happy', 'neutral', 'sad', 'surprise']

# Start the webcam
cap = cv2.VideoCapture(0)

# Load the face detector from OpenCV
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

while True:
    ret, frame = cap.read()
    if not ret:
        break

    # Convert to grayscale for face detection
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

    # Detect faces in the image
    faces = face_cascade.detectMultiScale(gray, scaleFactor=1.1, minNeighbors=5, minSize=(30, 30))

    for (x, y, w, h) in faces:
        # Draw a rectangle around the face
        face = frame[y:y+h, x:x+w]
        face_resized = cv2.resize(face, (48, 48))  # Resize the face to the model's expected input size
        face_resized = np.expand_dims(face_resized, axis=0)
        face_resized = np.expand_dims(face_resized, axis=-1)  # Add channel dimension for grayscale

        # Normalize the face image
        face_resized = face_resized / 255.0

        # Predict the emotion
        predictions = model.predict(face_resized)
        emotion_idx = np.argmax(predictions)
        emotion = emotion_labels[emotion_idx]

        # Define the color for the bounding box based on the emotion
        emotion_colors = {
            'angry': (0, 0, 255),
            'disgust': (0, 255, 0),
            'fear': (255, 0, 255),
            'happy': (0, 255, 255),
            'neutral': (128, 128, 128),
            'sad': (255, 0, 0),
            'surprise': (0, 165, 255)
        }

        # Draw the rectangle with the emotion color and label
        color = emotion_colors[emotion]
        cv2.rectangle(frame, (x, y), (x+w, y+h), color, 2)
        cv2.putText(frame, emotion, (x, y-10), cv2.FONT_HERSHEY_SIMPLEX, 1, color, 2)

    # Display the output frame
    cv2.imshow('Emotion Detection', frame)

    # Break loop on 'q' key press
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()

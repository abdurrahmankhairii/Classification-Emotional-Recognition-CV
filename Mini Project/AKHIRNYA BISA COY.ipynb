# %% [markdown]
# ### Libaries loading

# %%
# !pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\abdur\anaconda3\envs\tf-env\lib\site-packages (3.9.4)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\abdur\anaconda3\envs\tf-env\lib\site-packages (from matplotlib) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\abdur\anaconda3\envs\tf-env\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\abdur\anaconda3\envs\tf-env\lib\site-packages (from matplotlib) (4.55.6)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\abdur\anaconda3\envs\tf-env\lib\site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: numpy>=1.23 in c:\users\abdur\anaconda3\envs\tf-env\lib\site-packages (from matplotlib) (1.23.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\abdur\anaconda3\envs\tf-env\lib\site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\abdur\anaconda3\envs\tf-env\lib\site-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\abdur\anaconda3\envs\tf-env\lib\site-packages (from matplotlib) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\abdur\anaconda3\envs\tf-env\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\abdur\anaconda3\envs\tf-env\lib\site-packages (from matplotlib) (6.5.2)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\abdur\anaconda3\envs\tf-env\lib\site-packages (from importlib-resources>=3.2.0->matplotlib) (3.21.0)
# Requirement already satisfied: six>=1.5 in c:\users\abdur\anaconda3\envs\tf-env\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd

import torch

# %% [markdown]
# ### Hyperparameter initializing

# %%
RANDOM_STATE = 42
LEARNING_RATE = 0.0001
EPOCHS = 100
BATCH_SIZE = 32
NUM_CLASSES = 7

# %%
# manual seed
torch.manual_seed(RANDOM_STATE)

# %% [markdown]
# Check if there're any `GPU` appear

# %%
# !nvidia-smi
# Out:
# Tue Mar  4 08:03:30 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 571.96                 Driver Version: 571.96         CUDA Version: 12.8     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                  Driver-Model | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce RTX 4060 ...  WDDM  |   00000000:01:00.0 Off |                  N/A |
# | N/A   40C    P8              6W /   40W |    6715MiB /   8188MiB |      8%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |    0   N/A  N/A            4912    C+G   ...Browser\Application\brave.exe      N/A      |
# |    0   N/A  N/A           11240    C+G   ...Browser\Application\brave.exe      N/A      |
# |    0   N/A  N/A           36972      C   ...conda3\envs\tf-env\python.exe      N/A      |
# +-----------------------------------------------------------------------------------------+

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print('Using device:', device)
# Out:
# Using device: cpu

# %% [markdown]
# ## Data Exploring

# %%
train_path = 'C:/College/Semester 5/Computer Vision/Project/Mini Project/archive/train'
test_path = 'C:/College/Semester 5/Computer Vision/Project/Mini Project/archive/test'

# %%
import numpy as np
import cv2
import os
from sklearn.model_selection import train_test_split

# Paths to dataset folders
train_path = r"C:/College/Semester 5/Computer Vision/Project/Mini Project/archive/train"
test_path = r"C:/College/Semester 5/Computer Vision/Project/Mini Project/archive/test"

# Function to load images from a folder
def load_images_from_folder(folder_path):
    images = []
    labels = []  # Store labels if subfolders exist (e.g., 'happy', 'sad')
    
    for label in sorted(os.listdir(folder_path)):  # If categories are stored in subfolders
        label_path = os.path.join(folder_path, label)
        
        if os.path.isdir(label_path):  # Ensure it's a category folder
            for file in sorted(os.listdir(label_path)):
                if file.endswith(".jpg") or file.endswith(".png"):
                    img = cv2.imread(os.path.join(label_path, file), cv2.IMREAD_GRAYSCALE)
                    img = cv2.resize(img, (48, 48))  # Resize to 48x48
                    images.append(img)
                    labels.append(label)  # Store the label

    return np.array(images), np.array(labels)

# Load training and testing datasets
X_train, y_train = load_images_from_folder(train_path)
X_test, y_test = load_images_from_folder(test_path)

# Split validation set from training set (e.g., 80% train, 20% val)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=42)

# Store data in a dictionary
data = {
    "train": (X_train, y_train),
    "val": (X_val, y_val),
    "test": (X_test, y_test)
}

# Save as .npy file
np.save("fer13_imagedataset.npy", data)

print("File fer13_images.npy saved successfully!")
# Out:
# File fer13_images.npy saved successfully!

# %%
import torch
import numpy as np
from sklearn.preprocessing import LabelEncoder

# Load data
data_path = "fer13_imagedataset.npy"
data = np.load(data_path, allow_pickle=True).item()

X_train, y_train = data['train']
X_val, y_val = data['val']
X_test, y_test = data['test']

# %%
# Convert string labels to integers
label_encoder = LabelEncoder()
y_train = label_encoder.fit_transform(y_train)  # Convert labels to integers
y_val = label_encoder.transform(y_val)
y_test = label_encoder.transform(y_test)

# Convert NumPy arrays to PyTorch tensors
X_train = torch.tensor(X_train, dtype=torch.float32)
y_train = torch.tensor(y_train, dtype=torch.long)

X_val = torch.tensor(X_val, dtype=torch.float32)
y_val = torch.tensor(y_val, dtype=torch.long)

X_test = torch.tensor(X_test, dtype=torch.float32)
y_test = torch.tensor(y_test, dtype=torch.long)

print("Data successfully converted to tensors!")
print(f"X_train: {X_train.shape}, y_train: {y_train.shape}")
print(f"X_val: {X_val.shape}, y_val: {y_val.shape}")
print(f"X_test: {X_test.shape}, y_test: {y_test.shape}")
# Out:
# Data successfully converted to tensors!
# X_train: torch.Size([22967, 48, 48]), y_train: torch.Size([22967])
# X_val: torch.Size([5742, 48, 48]), y_val: torch.Size([5742])
# X_test: torch.Size([7178, 48, 48]), y_test: torch.Size([7178])

# %%
X_train.shape, y_train.shape, X_val.shape, y_val.shape, X_test.shape, y_test.shape
# Out:
# (torch.Size([22967, 48, 48]),
#  torch.Size([22967]),
#  torch.Size([5742, 48, 48]),
#  torch.Size([5742]),
#  torch.Size([7178, 48, 48]),
#  torch.Size([7178]))

# %%
# convert to type torch float32
X_train = X_train.type(torch.float32)
X_val = X_val.type(torch.float32)
X_test = X_test.type(torch.float32)

y_train = y_train.type(torch.long)
y_val = y_val.type(torch.long)
y_test = y_test.type(torch.long)

# %%
# convert to pytorch format (N, C, H, W)
X_train = X_train.unsqueeze(1)
X_val = X_val.unsqueeze(1)
X_test = X_test.unsqueeze(1)

X_train.shape, X_val.shape, X_test.shape
# Out:
# (torch.Size([22967, 1, 48, 48]),
#  torch.Size([5742, 1, 48, 48]),
#  torch.Size([7178, 1, 48, 48]))

# %%
# show unique value of y_train
y_train.unique()
# Out:
# tensor([0, 1, 2, 3, 4, 5, 6])

# %%
fig, axes = plt.subplots(ncols = 5, nrows = 7, figsize = (12, 7))

for i in range(7):
  tmp = X_train[y_train == i][45:50].squeeze()
  for j in range(5):
    axes[i, j].imshow(tmp[j], cmap = 'gray')
    axes[i, j].axis('off')
    axes[i, j].set_title(f"Label: {i}")

plt.tight_layout()
plt.show()

# %% [markdown]
# **Label and their emotion**
# |y |emotion|
# |-----|-----|
# |0| angry|
# |1| diggust|
# |2| scare|
# |3| happy|
# |4| sad|
# |5| supprise|
# |6| neutral|

# %%
emotions = np.array(['angry', 'disgust', 'scare', 'happy', 'sad', 'surprise', 'neutral'])

# %%
# Show the count of class
emotion_count = pd.Series(y_train).value_counts().sort_index()
emotion_count
# Out:
# 0    3216
# 1     344
# 2    3259
# 3    5741
# 4    3979
# 5    3853
# 6    2575
# Name: count, dtype: int64

# %%
plt.figure(figsize = (10, 7))
ax = sns.barplot(y = emotion_count,
            x = emotions)

for i, v in enumerate(emotion_count.values):
    ax.text(i, v + 1, str(v), ha='center', va='bottom', fontsize=10)

plt.xlabel("")
plt.ylabel("Count")
plt.title("Count of Class")
plt.show()

# %%
from sklearn.utils.class_weight import compute_class_weight

# %%
class_weights = compute_class_weight(class_weight = 'balanced',
                                     classes = np.unique(y_train),
                                     y = y_train.numpy())

class_weights = torch.tensor(class_weights, dtype=torch.float32).to(device)

# %%
class_weights
# Out:
# tensor([1.0202, 9.5378, 1.0068, 0.5715, 0.8246, 0.8515, 1.2742])

# %% [markdown]
# ## Modeling
#
#
# ### Data Augmentation

# %%
# !pip install torchvision
# Out:
# Collecting torchvision
#   Using cached torchvision-0.21.0-cp39-cp39-win_amd64.whl.metadata (6.3 kB)
# Requirement already satisfied: numpy in c:\users\abdur\anaconda3\envs\new_env\lib\site-packages (from torchvision) (2.0.2)
# Requirement already satisfied: torch==2.6.0 in c:\users\abdur\anaconda3\envs\new_env\lib\site-packages (from torchvision) (2.6.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\abdur\anaconda3\envs\new_env\lib\site-packages (from torchvision) (11.1.0)
# Requirement already satisfied: filelock in c:\users\abdur\anaconda3\envs\new_env\lib\site-packages (from torch==2.6.0->torchvision) (3.17.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\abdur\anaconda3\envs\new_env\lib\site-packages (from torch==2.6.0->torchvision) (4.12.2)
# Requirement already satisfied: networkx in c:\users\abdur\anaconda3\envs\new_env\lib\site-packages (from torch==2.6.0->torchvision) (3.2.1)
# Requirement already satisfied: jinja2 in c:\users\abdur\anaconda3\envs\new_env\lib\site-packages (from torch==2.6.0->torchvision) (3.1.5)
# Requirement already satisfied: fsspec in c:\users\abdur\anaconda3\envs\new_env\lib\site-packages (from torch==2.6.0->torchvision) (2024.12.0)
# Requirement already satisfied: sympy==1.13.1 in c:\users\abdur\anaconda3\envs\new_env\lib\site-packages (from torch==2.6.0->torchvision) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\abdur\anaconda3\envs\new_env\lib\site-packages (from sympy==1.13.1->torch==2.6.0->torchvision) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\abdur\anaconda3\envs\new_env\lib\site-packages (from jinja2->torch==2.6.0->torchvision) (3.0.2)
# Using cached torchvision-0.21.0-cp39-cp39-win_amd64.whl (1.6 MB)
# Installing collected packages: torchvision
# Successfully installed torchvision-0.21.0

# %%
# data augmentation
from torchvision.transforms import RandomHorizontalFlip, RandomRotation, RandomAffine, RandomPerspective, RandomResizedCrop, Compose

transforms = Compose([
    RandomHorizontalFlip(p = 0.5),
    RandomRotation(degrees = 15),
    RandomAffine(degrees = 15),
    RandomPerspective(),
    RandomResizedCrop(size = (48, 48))
])

# %%
# show the image before and after augmentation
fig, axes = plt.subplots(nrows = 1, ncols = 4, figsize = (10, 5))

axes[0].imshow(X_train[0].squeeze(), cmap = 'gray')
axes[0].set_title('Original Image')
axes[0].axis('off')

for i in range(1, 4):
    augmented_image = transforms(X_train[0].unsqueeze(0))
    axes[i].imshow(augmented_image.squeeze(), cmap = 'gray')
    axes[i].set_title('Augmented Image')
    axes[i].axis('off')

plt.tight_layout()
plt.show()

# %%
# using GPU
X_train = X_train.to(device)
y_train = y_train.to(device)

X_val = X_val.to(device)
y_val = y_val.to(device)

X_test = X_test.to(device)
y_test = y_test.to(device)

# %% [markdown]
# Then, apply this to the origin `X_train` and **concat** them together

# %%
# apply data augmentation
X_train_augmented = torch.stack([transforms(i) for i in X_train])

# %%
# merge the original and augmented data
X_train = torch.cat([X_train, X_train_augmented], dim = 0)
y_train = torch.cat([y_train, y_train], dim = 0)

# %%
X_train.shape
# Out:
# torch.Size([45934, 1, 48, 48])

# %%
# rescale the data
X_train = X_train / 255.
X_val = X_val / 255.
X_test = X_test / 255.

# %% [markdown]
# ### Model Defining

# %%
# !pip install torchsummary
# Out:
# Collecting torchsummary
#   Using cached torchsummary-1.5.1-py3-none-any.whl.metadata (296 bytes)
# Using cached torchsummary-1.5.1-py3-none-any.whl (2.8 kB)
# Installing collected packages: torchsummary
# Successfully installed torchsummary-1.5.1

# %%
from torch.utils.data import DataLoader, TensorDataset
from torch.nn import Module, Conv2d, Linear, MaxPool2d, ReLU, Dropout, BatchNorm2d , Flatten, Softmax
from torch.optim import Adam
from torchsummary import summary

# %%
# create dataloader
train_dataset = TensorDataset(X_train, y_train)
val_dataset = TensorDataset(X_val, y_val)
test_dataset = TensorDataset(X_test, y_test)

train_dataloader = DataLoader(train_dataset, batch_size = BATCH_SIZE,)
val_dataloader = DataLoader(val_dataset, batch_size = BATCH_SIZE,)
test_dataloader = DataLoader(test_dataset, batch_size = BATCH_SIZE,)

# %%
class CNN(Module):
    def __init__(self, channels, num_classes):
        super().__init__()

        # Convolutional layers
        self.conv1 = Conv2d(in_channels=channels, out_channels=32, kernel_size=(5, 5), padding=2)
        self.conv2 = Conv2d(in_channels=32, out_channels=64, kernel_size=(5, 5), padding=2)
        self.conv3 = Conv2d(in_channels=64, out_channels=128, kernel_size=(5, 5), padding=2)
        self.conv4 = Conv2d(in_channels=128, out_channels=512, kernel_size=(5, 5), padding=2)
        self.conv5 = Conv2d(in_channels=512, out_channels=1024, kernel_size=(3, 3), padding=1)

        # Batch normalization
        self.batchnorm1 = BatchNorm2d(num_features=32)
        self.batchnorm2 = BatchNorm2d(num_features=64)
        self.batchnorm3 = BatchNorm2d(num_features=128)
        self.batchnorm4 = BatchNorm2d(num_features=512)
        self.batchnorm5 = BatchNorm2d(num_features=1024)

        # Other layers
        self.maxpool = MaxPool2d(kernel_size=(2, 2))
        self.relu = ReLU()
        self.dropout = Dropout(p=0.2)

        # Fully connected layers
        self.flatten = Flatten()
        self.fc1 = Linear(in_features=1024, out_features=512)
        self.fc2 = Linear(in_features=512, out_features=128)
        self.fc3 = Linear(in_features=128, out_features=num_classes)
        self.softmax = Softmax(dim=1)

    

    def forward(self, X):
        # block 1
        X = self.conv1(X)
        X = self.batchnorm1(X)
        X = self.relu(X)
        X = self.maxpool(X)

        # block 2
        X = self.conv2(X)
        X = self.batchnorm2(X)
        X = self.relu(X)
        X = self.maxpool(X)

        # block 3
        X = self.conv3(X)
        X = self.batchnorm3(X)
        X = self.relu(X)
        X = self.maxpool(X)

        # block 4
        X = self.conv4(X)
        X = self.batchnorm4(X)
        X = self.relu(X)
        X = self.maxpool(X)
        X = self.dropout(X)

        # block 5
        X = self.conv5(X)
        X = self.batchnorm5(X)
        X = self.relu(X)
        X = self.maxpool(X)
        X = self.dropout(X)

        
        # fully connected layer
        X = self.flatten(X)
        X = self.fc1(X)
        X = self.relu(X)
        X = self.dropout(X)

        X = self.fc2(X)
        X = self.relu(X)
        X = self.dropout(X)

        X = self.fc3(X)
        return X

# %%
model = CNN(channels = 1, num_classes = NUM_CLASSES).to(device)

# %%
optimizer = Adam(params = model.parameters(), lr = LEARNING_RATE)

# %%
# loss fn
loss_fn = torch.nn.CrossEntropyLoss(weight=torch.tensor(class_weights, dtype=torch.float32).to(device))
# Out:
# C:\Users\abdur\AppData\Local\Temp\ipykernel_17604\2094615562.py:2: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   loss_fn = torch.nn.CrossEntropyLoss(weight=torch.tensor(class_weights, dtype=torch.float32).to(device))

# %%
summary(model, (1, 48, 48))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 32, 48, 48]             832
#        BatchNorm2d-2           [-1, 32, 48, 48]              64
#               ReLU-3           [-1, 32, 48, 48]               0
#          MaxPool2d-4           [-1, 32, 24, 24]               0
#             Conv2d-5           [-1, 64, 24, 24]          51,264
#        BatchNorm2d-6           [-1, 64, 24, 24]             128
#               ReLU-7           [-1, 64, 24, 24]               0
#          MaxPool2d-8           [-1, 64, 12, 12]               0
#             Conv2d-9          [-1, 128, 12, 12]         204,928
#       BatchNorm2d-10          [-1, 128, 12, 12]             256
#              ReLU-11          [-1, 128, 12, 12]               0
#         MaxPool2d-12            [-1, 128, 6, 6]               0
#            Conv2d-13            [-1, 512, 6, 6]       1,638,912
#       BatchNorm2d-14            [-1, 512, 6, 6]           1,024
#              ReLU-15            [-1, 512, 6, 6]               0
#         MaxPool2d-16            [-1, 512, 3, 3]               0
#           Dropout-17            [-1, 512, 3, 3]               0
#            Conv2d-18           [-1, 1024, 3, 3]       4,719,616
#       BatchNorm2d-19           [-1, 1024, 3, 3]           2,048
#              ReLU-20           [-1, 1024, 3, 3]               0
#         MaxPool2d-21           [-1, 1024, 1, 1]               0
#           Dropout-22           [-1, 1024, 1, 1]               0
#           Flatten-23                 [-1, 1024]               0
#            Linear-24                  [-1, 512]         524,800
#              ReLU-25                  [-1, 512]               0
#           Dropout-26                  [-1, 512]               0
#            Linear-27                  [-1, 128]          65,664
#              ReLU-28                  [-1, 128]               0
#           Dropout-29                  [-1, 128]               0
#            Linear-30                    [-1, 7]             903
# ================================================================
# Total params: 7,210,439
# Trainable params: 7,210,439
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 3.94
# Params size (MB): 27.51
# Estimated Total Size (MB): 31.45
# ----------------------------------------------------------------

# %% [markdown]
# ### Model Training and Testing Loops Defining

# %%
# traning loop
def train_epoch(model, dataloader, loss_fn, optimizer):
  # turn on train phase
  model.train()
  running_loss = 0.0
  correct = 0
  total = 0

  for inputs, labels in dataloader:
    inputs, labels = inputs.to(device), labels.to(device)

    # forward pass
    outputs = model(inputs)

    # calculate loss
    loss = loss_fn(outputs, labels)

    # zero gradient
    optimizer.zero_grad()

    # backpropagation
    loss.backward()

    # update
    optimizer.step()

    # save loss and accuracy
    running_loss += loss.item()
    _, predicted = torch.max(outputs.data, 1)
    total += labels.size(0)
    correct += (predicted == labels).sum().item()

  epoch_loss = running_loss / len(dataloader)
  epoch_acc = 100 * correct / total

  return epoch_loss, epoch_acc

# %%
# testing loop
def test_epoch(model, dataloader, loss_fn):
  # turn on test phase
  model.eval()
  correct = 0
  total = 0

  with torch.inference_mode():
    for inputs, labels in dataloader:
      inputs, labels = inputs.to(device), labels.to(device)
      outputs = model(inputs)
      _, predicted = outputs.max(1)
      total += labels.size(0)
      correct += (predicted == labels).sum().item()

  epoch_acc = 100 * correct / total

  return epoch_acc

# %% [markdown]
# ### Train the model through EPOCHS

# %%
# best acc
best_acc = 0.0
train_loss_list = []
train_acc_list = []
val_acc_list = []

for epoch in range(EPOCHS):
  train_loss, train_acc = train_epoch(model, train_dataloader, loss_fn, optimizer)
  val_acc = test_epoch(model, val_dataloader, loss_fn)

  train_loss_list.append(train_loss)
  train_acc_list.append(train_acc)
  val_acc_list.append(val_acc)

  # save best model
  if val_acc > best_acc:
    best_acc = val_acc
    torch.save(model.state_dict(), 'best_model.pth')

  print(f"Epoch [{epoch+1}/{EPOCHS}]")
  print(f"Train Loss: {train_loss:.4f} | Train Acc: {train_acc:.2f}%")
  print(f"Val Acc: {val_acc:.2f}%")
  print('-'*50)
# Out:
# Epoch [1/100]
# Train Loss: 1.8321 | Train Acc: 27.55%
# Val Acc: 39.13%
# --------------------------------------------------
# Epoch [2/100]
# Train Loss: 1.6548 | Train Acc: 36.01%
# Val Acc: 45.02%
# --------------------------------------------------
# Epoch [3/100]
# Train Loss: 1.5382 | Train Acc: 39.67%
# Val Acc: 47.63%
# --------------------------------------------------
# Epoch [4/100]
# Train Loss: 1.4311 | Train Acc: 43.28%
# Val Acc: 50.40%
# --------------------------------------------------
# Epoch [5/100]
# Train Loss: 1.3249 | Train Acc: 46.41%
# Val Acc: 51.39%
# --------------------------------------------------
# Epoch [6/100]
# Train Loss: 1.2355 | Train Acc: 49.46%
# Val Acc: 50.51%
# --------------------------------------------------
# Epoch [7/100]
# Train Loss: 1.1516 | Train Acc: 52.13%
# Val Acc: 52.06%
# --------------------------------------------------
# Epoch [8/100]
# Train Loss: 1.0802 | Train Acc: 54.89%
# Val Acc: 53.92%
# --------------------------------------------------
# Epoch [9/100]
# Train Loss: 1.0132 | Train Acc: 57.75%
# Val Acc: 56.55%
# --------------------------------------------------
# Epoch [10/100]
# Train Loss: 0.9500 | Train Acc: 60.05%
# Val Acc: 54.20%
# --------------------------------------------------
# Epoch [11/100]
# Train Loss: 0.8758 | Train Acc: 63.58%
# Val Acc: 52.21%
# --------------------------------------------------
# Epoch [12/100]
# Train Loss: 0.8036 | Train Acc: 65.99%
# Val Acc: 54.82%
# --------------------------------------------------
# Epoch [13/100]
# Train Loss: 0.7524 | Train Acc: 68.24%
# Val Acc: 55.57%
# --------------------------------------------------
# Epoch [14/100]
# Train Loss: 0.6945 | Train Acc: 70.97%
# Val Acc: 55.75%
# --------------------------------------------------
# Epoch [15/100]
# Train Loss: 0.6390 | Train Acc: 73.16%
# Val Acc: 56.91%
# --------------------------------------------------
# Epoch [16/100]
# Train Loss: 0.5934 | Train Acc: 75.17%
# Val Acc: 55.76%
# --------------------------------------------------
# Epoch [17/100]
# Train Loss: 0.5097 | Train Acc: 78.32%
# Val Acc: 52.19%
# --------------------------------------------------
# Epoch [18/100]
# Train Loss: 0.5040 | Train Acc: 79.34%
# Val Acc: 57.73%
# --------------------------------------------------
# Epoch [19/100]
# Train Loss: 0.4528 | Train Acc: 81.18%
# Val Acc: 57.04%
# --------------------------------------------------
# Epoch [20/100]
# Train Loss: 0.4297 | Train Acc: 82.10%
# Val Acc: 55.49%
# --------------------------------------------------
# Epoch [21/100]
# Train Loss: 0.3966 | Train Acc: 83.56%
# Val Acc: 55.75%
# --------------------------------------------------
# Epoch [22/100]
# Train Loss: 0.3549 | Train Acc: 85.12%
# Val Acc: 57.47%
# --------------------------------------------------
# Epoch [23/100]
# Train Loss: 0.3119 | Train Acc: 87.00%
# Val Acc: 55.82%
# --------------------------------------------------
# Epoch [24/100]
# Train Loss: 0.3187 | Train Acc: 86.84%
# Val Acc: 56.44%
# --------------------------------------------------
# Epoch [25/100]
# Train Loss: 0.2774 | Train Acc: 88.63%
# Val Acc: 55.68%
# --------------------------------------------------
# Epoch [26/100]
# Train Loss: 0.2864 | Train Acc: 88.32%
# Val Acc: 56.84%
# --------------------------------------------------
# Epoch [27/100]
# Train Loss: 0.2384 | Train Acc: 89.98%
# Val Acc: 56.18%
# --------------------------------------------------
# Epoch [28/100]
# Train Loss: 0.2256 | Train Acc: 90.59%
# Val Acc: 57.30%
# --------------------------------------------------
# Epoch [29/100]
# Train Loss: 0.2155 | Train Acc: 91.15%
# Val Acc: 56.88%
# --------------------------------------------------
# Epoch [30/100]
# Train Loss: 0.2056 | Train Acc: 91.63%
# Val Acc: 56.20%
# --------------------------------------------------
# Epoch [31/100]
# Train Loss: 0.2069 | Train Acc: 91.74%
# Val Acc: 57.75%
# --------------------------------------------------
# Epoch [32/100]
# Train Loss: 0.1847 | Train Acc: 92.46%
# Val Acc: 56.37%
# --------------------------------------------------
# Epoch [33/100]
# Train Loss: 0.1866 | Train Acc: 92.44%
# Val Acc: 57.56%
# --------------------------------------------------
# Epoch [34/100]
# Train Loss: 0.1586 | Train Acc: 93.48%
# Val Acc: 56.23%
# --------------------------------------------------
# Epoch [35/100]
# Train Loss: 0.1700 | Train Acc: 93.25%
# Val Acc: 56.77%
# --------------------------------------------------
# Epoch [36/100]
# Train Loss: 0.1610 | Train Acc: 93.70%
# Val Acc: 56.46%
# --------------------------------------------------
# Epoch [37/100]
# Train Loss: 0.1588 | Train Acc: 93.81%
# Val Acc: 57.91%
# --------------------------------------------------
# Epoch [38/100]
# Train Loss: 0.1175 | Train Acc: 95.22%
# Val Acc: 56.23%
# --------------------------------------------------
# Epoch [39/100]
# Train Loss: 0.1284 | Train Acc: 95.02%
# Val Acc: 56.81%
# --------------------------------------------------
# Epoch [40/100]
# Train Loss: 0.1227 | Train Acc: 95.25%
# Val Acc: 57.12%
# --------------------------------------------------
# Epoch [41/100]
# Train Loss: 0.1303 | Train Acc: 94.80%
# Val Acc: 57.70%
# --------------------------------------------------
# Epoch [42/100]
# Train Loss: 0.1241 | Train Acc: 95.26%
# Val Acc: 58.20%
# --------------------------------------------------
# Epoch [43/100]
# Train Loss: 0.0964 | Train Acc: 96.13%
# Val Acc: 57.16%
# --------------------------------------------------
# Epoch [44/100]
# Train Loss: 0.1147 | Train Acc: 95.57%
# Val Acc: 56.74%
# --------------------------------------------------
# Epoch [45/100]
# Train Loss: 0.1022 | Train Acc: 95.91%
# Val Acc: 54.30%
# --------------------------------------------------
# Epoch [46/100]
# Train Loss: 0.1098 | Train Acc: 95.76%
# Val Acc: 54.60%
# --------------------------------------------------
# Epoch [47/100]
# Train Loss: 0.1020 | Train Acc: 96.07%
# Val Acc: 57.91%
# --------------------------------------------------
# Epoch [48/100]
# Train Loss: 0.0978 | Train Acc: 96.36%
# Val Acc: 55.09%
# --------------------------------------------------
# Epoch [49/100]
# Train Loss: 0.1030 | Train Acc: 96.08%
# Val Acc: 56.51%
# --------------------------------------------------
# Epoch [50/100]
# Train Loss: 0.0825 | Train Acc: 96.80%
# Val Acc: 54.58%
# --------------------------------------------------
# Epoch [51/100]
# Train Loss: 0.0812 | Train Acc: 96.93%
# Val Acc: 57.66%
# --------------------------------------------------
# Epoch [52/100]
# Train Loss: 0.0930 | Train Acc: 96.55%
# Val Acc: 58.39%
# --------------------------------------------------
# Epoch [53/100]
# Train Loss: 0.0722 | Train Acc: 97.25%
# Val Acc: 57.51%
# --------------------------------------------------
# Epoch [54/100]
# Train Loss: 0.0807 | Train Acc: 96.97%
# Val Acc: 55.61%
# --------------------------------------------------
# Epoch [55/100]
# Train Loss: 0.0817 | Train Acc: 96.94%
# Val Acc: 54.89%
# --------------------------------------------------
# Epoch [56/100]
# Train Loss: 0.0781 | Train Acc: 96.93%
# Val Acc: 57.59%
# --------------------------------------------------
# Epoch [57/100]
# Train Loss: 0.0718 | Train Acc: 97.29%
# Val Acc: 56.15%
# --------------------------------------------------
# Epoch [58/100]
# Train Loss: 0.0690 | Train Acc: 97.46%
# Val Acc: 56.46%
# --------------------------------------------------
# Epoch [59/100]
# Train Loss: 0.1062 | Train Acc: 96.20%
# Val Acc: 56.97%
# --------------------------------------------------
# Epoch [60/100]
# Train Loss: 0.0555 | Train Acc: 97.91%
# Val Acc: 56.17%
# --------------------------------------------------
# Epoch [61/100]
# Train Loss: 0.0597 | Train Acc: 97.76%
# Val Acc: 57.37%
# --------------------------------------------------
# Epoch [62/100]
# Train Loss: 0.0775 | Train Acc: 97.13%
# Val Acc: 54.49%
# --------------------------------------------------
# Epoch [63/100]
# Train Loss: 0.0606 | Train Acc: 97.56%
# Val Acc: 56.95%
# --------------------------------------------------
# Epoch [64/100]
# Train Loss: 0.0693 | Train Acc: 97.37%
# Val Acc: 53.71%
# --------------------------------------------------
# Epoch [65/100]
# Train Loss: 0.0542 | Train Acc: 97.88%
# Val Acc: 55.57%
# --------------------------------------------------
# Epoch [66/100]
# Train Loss: 0.0581 | Train Acc: 97.74%
# Val Acc: 57.73%
# --------------------------------------------------
# Epoch [67/100]
# Train Loss: 0.0644 | Train Acc: 97.64%
# Val Acc: 56.03%
# --------------------------------------------------
# Epoch [68/100]
# Train Loss: 0.0633 | Train Acc: 97.68%
# Val Acc: 55.71%
# --------------------------------------------------
# Epoch [69/100]
# Train Loss: 0.0627 | Train Acc: 97.67%
# Val Acc: 54.91%
# --------------------------------------------------
# Epoch [70/100]
# Train Loss: 0.0752 | Train Acc: 97.19%
# Val Acc: 56.51%
# --------------------------------------------------
# Epoch [71/100]
# Train Loss: 0.0596 | Train Acc: 97.79%
# Val Acc: 56.37%
# --------------------------------------------------
# Epoch [72/100]
# Train Loss: 0.0640 | Train Acc: 97.72%
# Val Acc: 57.89%
# --------------------------------------------------
# Epoch [73/100]
# Train Loss: 0.0426 | Train Acc: 98.35%
# Val Acc: 55.57%
# --------------------------------------------------
# Epoch [74/100]
# Train Loss: 0.0603 | Train Acc: 97.82%
# Val Acc: 56.27%
# --------------------------------------------------
# Epoch [75/100]
# Train Loss: 0.0524 | Train Acc: 98.03%
# Val Acc: 57.12%
# --------------------------------------------------
# Epoch [76/100]
# Train Loss: 0.0465 | Train Acc: 98.26%
# Val Acc: 57.45%
# --------------------------------------------------
# Epoch [77/100]
# Train Loss: 0.0460 | Train Acc: 98.23%
# Val Acc: 57.42%
# --------------------------------------------------
# Epoch [78/100]
# Train Loss: 0.0483 | Train Acc: 98.18%
# Val Acc: 57.12%
# --------------------------------------------------
# Epoch [79/100]
# Train Loss: 0.0415 | Train Acc: 98.41%
# Val Acc: 57.82%
# --------------------------------------------------
# Epoch [80/100]
# Train Loss: 0.0708 | Train Acc: 97.57%
# Val Acc: 56.30%
# --------------------------------------------------
# Epoch [81/100]
# Train Loss: 0.0412 | Train Acc: 98.40%
# Val Acc: 56.37%
# --------------------------------------------------
# Epoch [82/100]
# Train Loss: 0.0573 | Train Acc: 97.99%
# Val Acc: 55.69%
# --------------------------------------------------
# Epoch [83/100]
# Train Loss: 0.0685 | Train Acc: 98.09%
# Val Acc: 56.22%
# --------------------------------------------------
# Epoch [84/100]
# Train Loss: 0.0587 | Train Acc: 98.21%
# Val Acc: 56.88%
# --------------------------------------------------
# Epoch [85/100]
# Train Loss: 0.0437 | Train Acc: 98.42%
# Val Acc: 56.69%
# --------------------------------------------------
# Epoch [86/100]
# Train Loss: 0.0579 | Train Acc: 97.87%
# Val Acc: 54.35%
# --------------------------------------------------
# Epoch [87/100]
# Train Loss: 0.0475 | Train Acc: 98.15%
# Val Acc: 56.65%
# --------------------------------------------------
# Epoch [88/100]
# Train Loss: 0.0388 | Train Acc: 98.49%
# Val Acc: 57.52%
# --------------------------------------------------
# Epoch [89/100]
# Train Loss: 0.0435 | Train Acc: 98.40%
# Val Acc: 55.61%
# --------------------------------------------------
# Epoch [90/100]
# Train Loss: 0.0376 | Train Acc: 98.58%
# Val Acc: 56.91%
# --------------------------------------------------
# Epoch [91/100]
# Train Loss: 0.0561 | Train Acc: 97.99%
# Val Acc: 56.65%
# --------------------------------------------------
# Epoch [92/100]
# Train Loss: 0.0347 | Train Acc: 98.63%
# Val Acc: 57.40%
# --------------------------------------------------
# Epoch [93/100]
# Train Loss: 0.0524 | Train Acc: 98.09%
# Val Acc: 57.31%
# --------------------------------------------------
# Epoch [94/100]
# Train Loss: 0.0359 | Train Acc: 98.62%
# Val Acc: 56.41%
# --------------------------------------------------
# Epoch [95/100]
# Train Loss: 0.0574 | Train Acc: 98.05%
# Val Acc: 56.11%
# --------------------------------------------------
# Epoch [96/100]
# Train Loss: 0.0347 | Train Acc: 98.63%
# Val Acc: 55.56%
# --------------------------------------------------
# Epoch [97/100]
# Train Loss: 0.0413 | Train Acc: 98.52%
# Val Acc: 55.47%
# --------------------------------------------------
# Epoch [98/100]
# Train Loss: 0.0439 | Train Acc: 98.40%
# Val Acc: 58.19%
# --------------------------------------------------
# Epoch [99/100]
# Train Loss: 0.0428 | Train Acc: 98.45%
# Val Acc: 56.77%
# --------------------------------------------------
# Epoch [100/100]
# Train Loss: 0.0391 | Train Acc: 98.53%
# Val Acc: 56.41%
# --------------------------------------------------

# %% [markdown]
# Plot the training curve and accuracy curve to see what happened

# %%
fig, axes = plt.subplots(ncols = 2, nrows = 1, figsize = (12, 5))

# Plot training curve
sns.lineplot(x = range(1, EPOCHS+1), y = train_loss_list, ax = axes[0], label = "Training loss")
axes[0].set_title("Training Curve")
axes[0].set_xlabel("Epochs")
axes[0].set_ylabel("Loss")

# Plot accuracy curve
sns.lineplot(x = range(1, EPOCHS+1), y = train_acc_list, ax = axes[1], label = "Train accuracy")
sns.lineplot(x = range(1, EPOCHS+1), y = val_acc_list, ax = axes[1], label = "Val_accuracy")
axes[1].set_title("Accuracy Curve")
axes[1].set_xlabel("Epochs")
axes[1].set_ylabel("Accuracy")

plt.tight_layout()
plt.show()

# %%
from sklearn.metrics import confusion_matrix, classification_report, f1_score, accuracy_score

# %%
y_pred = []
y_true = []

model.load_state_dict(torch.load('./best_model.pth'))
model.eval()

with torch.inference_mode():
  for inputs, labels in test_dataloader:
    inputs, labels = inputs.to(device), labels.to(device)
    outputs = model(inputs)
    _, predicted = outputs.max(1)
    y_pred.extend(predicted.cpu().numpy())
    y_true.extend(labels.cpu().numpy())

  print(classification_report(y_true, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.48      0.52      0.50       958
#            1       0.53      0.48      0.50       111
#            2       0.51      0.34      0.41      1024
#            3       0.72      0.83      0.77      1774
#            4       0.47      0.61      0.53      1233
#            5       0.52      0.37      0.43      1247
#            6       0.76      0.74      0.75       831
#
#     accuracy                           0.59      7178
#    macro avg       0.57      0.56      0.56      7178
# weighted avg       0.58      0.59      0.58      7178

# %%
print("F1 score macro:", f1_score(y_true, y_pred, average = 'macro'))
# Out:
# F1 score macro: 0.5553371949551403

# %%
print("Accuracy:", accuracy_score(y_true, y_pred))
# Out:
# Accuracy: 0.585260518250209

# %%
f1_scores = f1_score(y_true, y_pred, average=None)

f1_data = pd.DataFrame({
    'Emotion': emotions,
    'F1-Score': f1_scores
})

# %%
fig, axes = plt.subplots(ncols=2, nrows=1, figsize=(12, 5))

#----F1 SCORE PLOT-------
sns.barplot(x='Emotion', y='F1-Score', data=f1_data, ax=axes[0])
axes[0].set_title("F1-Score")
axes[0].set_xlabel("")
axes[0].set_ylabel("F1-Score")

for i, bar in enumerate(axes[0].containers[0]):  # containers[0] contain bars
    value = bar.get_height()
    axes[0].text(bar.get_x() + bar.get_width() / 2, value + 0.01,  # label position
                 f"{value:.2f}", ha='center', va='bottom', fontsize=10)


#----COUNTPLOT-------
sns.barplot(y=emotion_count, x=emotions, ax=axes[1])
axes[1].set_title("Count")
axes[1].set_xlabel("")
axes[1].set_ylabel("Count")

for i, bar in enumerate(axes[1].containers[0]):
    value = bar.get_height()
    axes[1].text(bar.get_x() + bar.get_width() / 2, value + 1,
                 f"{int(value)}", ha='center', va='bottom', fontsize=10)


plt.tight_layout()
plt.show()

# %%
# confusion matrix heatmap
cm = confusion_matrix(y_true, y_pred)

plt.figure(figsize=(10, 7))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=emotions, yticklabels=emotions)

plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')

plt.show()

# %%
import torch

# Save the entire model
torch.save(model, 'emotion_model_bisa.pth')
print("Model saved to emotion_model_bisa.pth")

# OR (Recommended) Save only the model's state_dict
torch.save(model.state_dict(), 'emotion_model_weights.pth')
print("Model weights saved to emotion_model_weights.pth")
# Out:
# Model saved to emotion_model_bisa.pth
# Model weights saved to emotion_model_weights.pth

# %%
# show 25 random test image and model predictions of them
fig, axes = plt.subplots(ncols = 5, nrows = 5, figsize = (10, 8))
axes = axes.flatten()

for i in range(25):
  idx = np.random.randint(0, len(X_test))
  image = X_test[idx]
  label = y_test[idx]
  pred = y_pred[idx]

  if label == pred:
    title_color = 'green'
  else:
    title_color = 'red'
  
  axes[i].imshow(image.squeeze().cpu().numpy(), cmap = 'gray')
  axes[i].set_title(f"Actual: {emotions[label]} \n Predicted: {emotions[pred]}", color = title_color)
  axes[i].axis('off')

plt.tight_layout()
plt.show()

# %%
import cv2
import numpy as np
import torch
import torch.nn.functional as F
from torchvision import transforms

# Define the model architecture (Fixed)
class CNN(torch.nn.Module):
    def __init__(self):
        super(CNN, self).__init__()
        self.conv1 = torch.nn.Conv2d(1, 32, kernel_size=3, padding=1)
        self.conv2 = torch.nn.Conv2d(32, 64, kernel_size=3, padding=1)
        self.pool = torch.nn.MaxPool2d(2, 2)  # Added pooling to downsample
        self.fc1 = torch.nn.Linear(64 * 56 * 56, 128)  # Adjusted input size after pooling
        self.fc2 = torch.nn.Linear(128, 7)  # 7 emotion classes

    def forward(self, x):
        x = self.pool(F.relu(self.conv1(x)))
        x = self.pool(F.relu(self.conv2(x)))
        x = torch.flatten(x, start_dim=1)
        x = F.relu(self.fc1(x))
        x = self.fc2(x)
        return x

# Load the trained model
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = CNN().to(device)
model.load_state_dict(torch.load('emotion_model_bisa.pth', map_location=device))
model.eval()

# Emotion labels and colors
emotion_labels = ['angry', 'disgust', 'fear', 'happy', 'neutral', 'sad', 'surprise']
emotion_colors = {
    'angry': (0, 0, 255),       # Red
    'disgust': (0, 255, 0),      # Green
    'fear': (255, 0, 255),       # Purple
    'happy': (0, 255, 255),      # Yellow
    'neutral': (128, 128, 128),  # Gray
    'sad': (255, 0, 0),          # Blue
    'surprise': (0, 165, 255)    # Orange
}

# Confidence threshold
CONFIDENCE_THRESHOLD = 0.2

# Open the webcam
cap = cv2.VideoCapture(0)
if not cap.isOpened():
    print("Error: Could not open webcam.")
    exit()

# Load face detector
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

# Define preprocessing transformations
transform = transforms.Compose([
    transforms.ToPILImage(),
    transforms.Resize((224, 224)),  # Resize to match model input
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.5], std=[0.5])
])

while True:
    ret, frame = cap.read()
    if not ret:
        print("Error: Failed to capture frame.")
        break

    # Convert frame to grayscale for face detection
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

    # Detect faces in the frame
    faces = face_cascade.detectMultiScale(gray, scaleFactor=1.2, minNeighbors=6, minSize=(30, 30))

    for (x, y, w, h) in faces:
        # Extract and preprocess the face
        face = gray[y:y+h, x:x+w]
        face = cv2.resize(face, (224, 224))  # Resize to 224x224
        face = np.expand_dims(face, axis=0)  # Add single-channel dimension
        face_tensor = torch.from_numpy(face).float().unsqueeze(0).unsqueeze(0).to(device)  # Corrected tensor format

        # Predict emotion
        with torch.no_grad():
            output = model(face_tensor)
            probabilities = F.softmax(output, dim=1).cpu().numpy()[0]

        max_confidence = np.max(probabilities)
        emotion_idx = np.argmax(probabilities)

        # If confidence is below threshold, display "Uncertain"
        if max_confidence < CONFIDENCE_THRESHOLD:
            emotion = "Uncertain"
            color = (128, 128, 128)  # Gray
            label = "Uncertain"
        else:
            emotion = emotion_labels[emotion_idx]
            color = emotion_colors[emotion]
            label = f"{emotion} ({max_confidence:.2f})"

        # Draw rectangle and label
        cv2.rectangle(frame, (x, y), (x+w, y+h), color, 2)
        cv2.putText(frame, label, (x, y-10), cv2.FONT_HERSHEY_SIMPLEX, 0.9, color, 2)

    # Display the frame
    cv2.imshow('Real-Time Emotion Detection', frame)

    # Exit on 'q' key
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Cleanup
cap.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# UnpicklingError                           Traceback (most recent call last)
# Cell In[61], line 28
#      26 device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
#      27 model = CNN().to(device)
# ---> 28 model.load_state_dict(torch.load('emotion_model_bisa.pth', map_location=device))
#      29 model.eval()
#      31 # Emotion labels and colors
#
# File ~\anaconda3\envs\new_env\lib\site-packages\torch\serialization.py:1470, in load(f, map_location, pickle_module, weights_only, mmap, **pickle_load_args)
#    1462                 return _load(
#    1463                     opened_zipfile,
#    1464                     map_location,
#    (...)
#    1467                     **pickle_load_args,
#    1468                 )
#    1469             except pickle.UnpicklingError as e:
# -> 1470                 raise pickle.UnpicklingError(_get_wo_message(str(e))) from None
#    1471         return _load(
#    1472             opened_zipfile,
#    1473             map_location,
#    (...)
#    1476             **pickle_load_args,
#    1477         )
#    1478 if mmap:
#
# UnpicklingError: Weights only load failed. This file can still be loaded, to do so you have two options, do those steps only if you trust the source of the checkpoint.
# 	(1) In PyTorch 2.6, we changed the default value of the `weights_only` argument in `torch.load` from `False` to `True`. Re-running `torch.load` with `weights_only` set to `False` will likely succeed, but it can result in arbitrary code execution. Do it only if you got the file from a trusted source.
# 	(2) Alternatively, to load with `weights_only=True` please check the recommended steps in the following error message.
# 	WeightsUnpickler error: Unsupported global: GLOBAL __main__.CNN was not an allowed global by default. Please use `torch.serialization.add_safe_globals([CNN])` or the `torch.serialization.safe_globals([CNN])` context manager to allowlist this global if you trust this class/function.
#
# Check the documentation of torch.load to learn more about types accepted by default with weights_only https://pytorch.org/docs/stable/generated/torch.load.html.
